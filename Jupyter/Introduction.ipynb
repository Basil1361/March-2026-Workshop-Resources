# %% [markdown]
# # 1. Our Mission

# %%
from IPython.display import display, HTML

display(HTML("""
<div style="background-color:#2C3E50;color:white;padding:20px;border-radius:10px;border:2px solid #E67E22;">
  <h2 style="font-family:'Comic Sans MS','Comic Sans',cursive !important; color:#E67E22; margin-top:0;">
    🎯 Our Mission
  </h2>

  <ul style="font-family:Verdana,sans-serif;font-size:16px;line-height:1.8;">
    <li style="color:#AED6F1;">
      <span style="font-family:Verdana,sans-serif; font-weight:700; color:#5DADE2;">Spark Interest</span>
      in the field of Data Analyst and Data Science (ML)
    </li>

    <li style="color:#A9DFBF;">
      <span style="font-family:'Verdana',sans-serif; font-weight:700; color:#52BE80;">Teach basic coding</span>
      to students, exploring around Python Libraries
    </li>

    <li style="color:#D7BDE2;">
      <span style="font-family:'Verdana',sans-serif; font-weight:700; color:#AF7AC5;">Ensure students</span>
      can solve problems critically, creatively and innovately
    </li>
  </ul>

  <h2 style="font-family:'Comic Sans MS','Comic Sans',cursive !important; color:#E67E22; margin-top:0;">🎯 Content:</h2>
    <ul style="font-family:Verdana,sans-serif;font-size:16px;line-height:1.8;">
      <li style = "color:#AED6F1">
        <span style="font-family:'Verdana',sans-serif; font-weight:700; color:#5DADE2;">Introduction and Differences</span>
         between Data Science (DS) and Data Analyst (DA)
        </li>
      <li style = "color:#A9DFBF">
        <span style="font-family:'Verdana',sans-serif; font-weight:700; color:#52BE80;">Interactive Lessons</span>
        on sorting values, graphs and Machine Learning via Pandas, Matplotlib and Scikit-Learn</li>
      <li style = "color:#D7BDE2">
        <span style="font-family:'Verdana',sans-serif; font-weight:700; color:#AF7AC5;">In Depth</span>
          Questions and guidance</li>
    </ul>
</div>
"""))
# Out:
# <div style="background-color:#2C3E50;color:white;padding:20px;border-radius:10px;border:2px solid #E67E22;">
#   <h2 style="font-family:'Comic Sans MS','Comic Sans',cursive !important; color:#E67E22; margin-top:0;">
#     🎯 Our Mission
#   </h2>
#
#   <ul style="font-family:Verdana,sans-serif;font-size:16px;line-height:1.8;">
#     <li style="color:#AED6F1;">
#       <span style="font-family:Verdana,sans-serif; font-weight:700; color:#5DADE2;">Spark Interest</span>
#       in the field of Data Analyst and Data Science (ML)
#     </li>
#
#     <li style="color:#A9DFBF;">
#       <span style="font-family:'Verdana',sans-serif; font-weight:700; color:#52BE80;">Teach basic coding</span>
#       to students, exploring around Python Libraries
#     </li>
#
#     <li style="color:#D7BDE2;">
#       <span style="font-family:'Verdana',sans-serif; font-weight:700; color:#AF7AC5;">Ensure students</span>
#       can solve problems critically, creatively and innovately
#     </li>
#   </ul>
#
#
#
# ...

# %% [markdown]
# # 2. Our Committes

# %%
from IPython.display import display, HTML

display(HTML("""
<div style="background-color:#2C3E50;color:white;padding:20px;border-radius:10px;border:3px solid #E67E22">
        <h2 style="font-family: Comic Sans MS, Comic Sans;color:#E67E22; margin-top:0">👤 Meet Our Committees:</h2>
        
        <ul style="font-family:Verdana,sans-serif;font-size:16px;line-height:1.8;">
            <li style="color:#AED6F1;font-family: Georgia;font-weight:700;"> Jia Jie ➡️ (main-host)</li>
            <li style="color:#A9DFBF;font-family: Georgia;font-weight:700;"> Joel Ng ➡️(committee)</li>
            <li style="color:#D7BDE2;font-family: Georgia;font-weight:700;"> Yun Yi ➡️ (committee)</li>
            <li style="color:#FFEE91;font-family: Georgia;font-weight:700;"> Vithran ➡️ (committee)</li>
            <li style="color:#FF941E;font-family: Georgia;font-weight:700;"> Yahaya ➡️ (committee)</li>
            <li style="color:#FF937E;font-family: Georgia;font-weight:700;"> Jia Yi ➡️ (logistics)</li>
        </ul>
</div>
"""))
# Out:
# <div style="background-color:#2C3E50;color:white;padding:20px;border-radius:10px;border:3px solid #E67E22">
#         <h2 style="font-family: Comic Sans MS, Comic Sans;color:#E67E22; margin-top:0">👤 Meet Our Committees:</h2>
#
#         <ul style="font-family:Verdana,sans-serif;font-size:16px;line-height:1.8;">
#             <li style="color:#AED6F1;font-family: Georgia;font-weight:700;"> Jia Jie ➡️ (main-host)</li>
#             <li style="color:#A9DFBF;font-family: Georgia;font-weight:700;"> Joel Ng ➡️(committee)</li>
#             <li style="color:#D7BDE2;font-family: Georgia;font-weight:700;"> Yun Yi ➡️ (committee)</li>
#             <li style="color:#FFEE91;font-family: Georgia;font-weight:700;"> Vithran ➡️ (committee)</li>
#             <li style="color:#FF941E;font-family: Georgia;font-weight:700;"> Yahaya ➡️ (committee)</li>
#             <li style="color:#FF937E;font-family: Georgia;font-weight:700;"> Jia Yi ➡️ (logistics)</li>
#         </ul>
# </div>

# %% [markdown]
# # 3. Table Form

# %%
from IPython.display import display, HTML

display(HTML("""
<div style="background-color:#2C3E50;color:white;padding:20px;border-radius:10px;border:2px solid #E67E22;">
  <h2 style="font-family:'Comic Sans MS','Comic Sans',cursive !important; color:#E67E22; margin-top:0; text-align:center;">
    📊 Data Science vs Data Analyst
  </h2>

  <h3 style="color:#5DADE2; font-family:Verdana,sans-serif;">🤝 Similarities</h3>
  <ul style="font-family:Verdana,sans-serif;font-size:16px;line-height:1.8;">
      <li style="color:#AED6F1;">Both roles aim to <span style="color:#5DADE2; font-weight:bold;">extract insights</span> from data to support decision-making.</li>
      <li style="color:#A9DFBF;">Both require skills in <span style="color:#52BE80; font-weight:bold;">data cleaning</span>, manipulation, and visualization.</li>
      <li style="color:#D7BDE2;">Both often use <span style="color:#AF7AC5; font-weight:bold;">SQL</span> and programming languages like Python or R.</li>
  </ul>

  <h3 style="color:#F5C857; font-family:Verdana,sans-serif;">⚖️ Differences</h3>
  <center>
    <table style="width:100%; border-collapse: collapse; font-family:Verdana,sans-serif; color: white; margin-top:10px;">
        <thead>
            <tr style="background-color:#E67E22; color:white;">
                <th style="padding:12px; border: 1px solid #E67E22;">Feature</th>
                <th style="padding:12px; border: 1px solid #E67E22;">Data Analyst</th>
                <th style="padding:12px; border: 1px solid #E67E22;">Data Scientist</th>
            </tr>
        </thead>
        <tbody>
            <tr>
                <td style="padding:10px; border: 1px solid #5D6D7E; font-weight:bold; color:#AED6F1; background-color:#34495E;">Primary Focus</td>
                <td style="padding:10px; border: 1px solid #5D6D7E;">Analyzing <b>past/present</b> data to answer specific business questions.</td>
                <td style="padding:10px; border: 1px solid #5D6D7E;">Predicting <b>future</b> trends and building models to solve complex problems.</td>
            </tr>
            <tr>
                <td style="padding:10px; border: 1px solid #5D6D7E; font-weight:bold; color:#AED6F1; background-color:#34495E;">Key Tools</td>
                <td style="padding:10px; border: 1px solid #5D6D7E;">Excel, SQL, Tableau, Power BI, Python (Basic).</td>
                <td style="padding:10px; border: 1px solid #5D6D7E;">Python, R, TensorFlow, PyTorch, Hadoop, Spark.</td>
            </tr>
            <tr>
                <td style="padding:10px; border: 1px solid #5D6D7E; font-weight:bold; color:#AED6F1; background-color:#34495E;">Output</td>
                <td style="padding:10px; border: 1px solid #5D6D7E;">Reports, Dashboards, Ad-hoc Analysis.</td>
                <td style="padding:10px; border: 1px solid #5D6D7E;">Predictive Models, Machine Learning Algorithms, Data Products.</td>
            </tr>
        </tbody>
    </table>
  </center>
</div>
"""))
# Out:
# <div style="background-color:#2C3E50;color:white;padding:20px;border-radius:10px;border:2px solid #E67E22;">
#   <h2 style="font-family:'Comic Sans MS','Comic Sans',cursive !important; color:#E67E22; margin-top:0; text-align:center;">
#     📊 Data Science vs Data Analyst
#   </h2>
#
#   <h3 style="color:#5DADE2; font-family:Verdana,sans-serif;">🤝 Similarities</h3>
#   <ul style="font-family:Verdana,sans-serif;font-size:16px;line-height:1.8;">
#       <li style="color:#AED6F1;">Both roles aim to <span style="color:#5DADE2; font-weight:bold;">extract insights</span> from data to support decision-making.</li>
#       <li style="color:#A9DFBF;">Both require skills in <span style="color:#52BE80; font-weight:bold;">data cleaning</span>, manipulation, and visualization.</li>
#       <li style="color:#D7BDE2;">Both often use <span style="color:#AF7AC5; font-weight:bold;">SQL</span> and programming languages like Python or R.</li>
#   </ul>
#
# ...
